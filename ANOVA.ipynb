# %% [markdown]
# # ANOVA (ANalysis Of VAriance: 분산 분석)

# %% [markdown]
# 이번 노트북에서는 분산분석에 대해서 알아보려고 한다.
#
# 분산분석은 여러 그룹간의 평균의 차이가 통계적으로 유의미 한지를 판단하기 위한 시험법이다.
#
# T-Test와 비슷한 개념이지만 그룹의 수가 2개 이상일때 사용한다는 점이 다르다.

# %%
# %matplotlib inline
import scipy.stats as stats
import pandas as pd
import urllib
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 분산의 중요성

# %% [markdown]
# 아래 두 그림은 평균은 같지만 분산 값이 다름으로 인해 전체적인 데이터의 모습이 다르다는 것을 나타낸다.

# %% [markdown]
# ##### 분산 = 0.1

# %%
centers = [5,5.3,4.5]
std = 0.1
colors = 'brg'

data_1 = []
for i in range(3):
    data_1.append(stats.norm(centers[i],std).rvs(100))
    plt.plot(np.arange(len(data_1[i]))+i*len(data_1[0]),data_1[i],'.',color=colors[i])

# %% [markdown]
# ##### 분산 = 2

# %%
std_2 = 2
data_2 = []
for i in range(3):
    data_2.append(stats.norm(centers[i],std_2).rvs(100))
    plt.plot(np.arange(len(data_1[i]))+i*len(data_2[0]),data_2[i],'.',color=colors[i])

# %% [markdown]
# 분산이 클수록 집단의 평균값의 차이가 무의미 해진다.
#
# 이를 통해 2가지를 알 수 있다.
#
# 첫 번째, 집단 평균값의 분산이 클수록 평균값의 차이가 분명해 진다.
#
# 두 번째, 집단 내 분산이 작을 수록 평균값의 차이가 분명해진다.

# %% [markdown]
# ## 일원분산분석(one-way ANOVA)

# %% [markdown]
# 일원분산분석은 종속변인은 1개이며, 독립변인의 집단도 1개인 경우이다.
#
# 한가지 변수의 변화가 결과 변수에 미치는 영향을 보기 위해 사용된다.

# %% [markdown]
# ### 예시

# %% [markdown]
# 22명의 심장 우회 수술을 받은 환자를 다음의 3가지 그룹으로 나누었습니다.
#
# - Group I: 50% 아산화 질소(nitrous oxide)와 50%의 산소(oxygen) 혼합물을 24시간 동안 흡입한 환자
# - Group II: 50% 아산화 질소와 50% 산소 혼합물을 수술 받는 동안만 흡입한 환자
# - Group III: 아산화 질소 없이 오직 35-50%의 산소만 24시간동안 처리한 환자
#
# 그런 다음 적혈구의 엽산 수치를 24시간 이후에 측정하였습니다.

# %%
# url로 데이터 얻어오기
url = 'https://raw.githubusercontent.com/thomas-haslwanter/statsintro_python/master/ipynb/Data/data_altman/altman_910.txt'
data = np.genfromtxt(urllib.request.urlopen(url), delimiter=',')

# Sort them into groups, according to column 1
group1 = data[data[:,1]==1,0]
group2 = data[data[:,1]==2,0]
group3 = data[data[:,1]==3,0]


# matplotlib plotting
plot_data = [group1, group2, group3]
ax = plt.boxplot(plot_data)
plt.show()

# %% [markdown]
# Boxplot에서 볼 수 있듯이, 평균값의 차이가 실제로 의미가 있는 차이인지, 분산이 커서 그런것인지 애매한 상황이다.
#
# 이런 상황에서 분산분석을 통해 통계적 유의성을 알아 볼 수 있다.

# %%
# 경고 메세지 무시하기
import warnings
warnings.filterwarnings('ignore')

df = pd.DataFrame(data, columns=['value', 'treatment'])    

# the "C" indicates categorical data
model = ols('value ~ C(treatment)', df).fit()

print(anova_lm(model))
# Out:
#                 df        sum_sq      mean_sq         F    PR(>F)
# C(treatment)   2.0  15515.766414  7757.883207  3.711336  0.043589
# Residual      19.0  39716.097222  2090.320906       NaN       NaN

# %% [markdown]
# p-value의 값이 유의수준(5%)보다 작기 때문에 그룹간 평균의 차이는 유의미하다 볼수 있다.

# %% [markdown]
# ## 이원분산분석(two-way ANOVA)

# %% [markdown]
# 독립변인의 수가 두 개 이상일 때 집단 간 차이가 유의한지를 검증하는 데 사용한다.
#
# 상호작용효과(Interaction effect), 한 변수의 변화가 결과에 미치는 영향이 다른 변수의 수준에 따라 달라지는지를 확인하기 위해 사용되어진다.

# %% [markdown]
# ### 예제

# %% [markdown]
# 태아의 머리 둘레 측정 데이터이다. 4명의 관측자가 3명의 태아를 대상으로 측정을 했다.
#
# 이를 통해서 초음파로 태아의 머리 둘레측정 데이터가 재현성이 있는지를 조사하였다.

# %%
# Feature가 2개다
inFile = 'altman_12_6.txt'
url_base = 'https://raw.githubusercontent.com/thomas-haslwanter/statsintro_python/master/ipynb/Data/data_altman/'
url = url_base + inFile
data = np.genfromtxt(urllib.request.urlopen(url), delimiter=',')

# Bring them in dataframe-format
df = pd.DataFrame(data, columns=['head_size', 'fetus', 'observer'])
# df.tail()

# 태아별 머리 둘레 plot 만들기
df.boxplot(column = 'head_size', by='fetus' , grid = False)

# %% [markdown]
# Boxplot을 통해서는 태아 3명의 머리 둘레는 차이가 있어 보인다.

# %%
formula = 'head_size ~ C(fetus) + C(observer) + C(fetus):C(observer)'
lm = ols(formula, df).fit()
print(anova_lm(lm))
# Out:
#                         df      sum_sq     mean_sq            F        PR(>F)
# C(fetus)               2.0  324.008889  162.004444  2113.101449  1.051039e-27
# C(observer)            3.0    1.198611    0.399537     5.211353  6.497055e-03
# C(fetus):C(observer)   6.0    0.562222    0.093704     1.222222  3.295509e-01
# Residual              24.0    1.840000    0.076667          NaN           NaN

# %% [markdown]
# P-value 가 0.05 이상 이다. 따라서 귀무가설을 기각할 수 없고. 측정자와 태아의 머리둘레값에는 연관성이 없다고 할 수 있다.
#
# 측정하는 사람이 달라도 머리 둘레값은 일정하는 것이다.
