# %%
from IPython.display import Image

# %% [markdown]
# ## 고유값과 고유벡터

# %% [markdown]
# 행렬 A를 선형변환으로 보았을때 선형변환 A에 의하 변환 결과가 자기 자신의 상수배가 되는
# 0이 아닌 벡터를 고유벡터(eigenvector)라 하고 이 상수배 값을 고유값(eigenvalue)라 한다.

# %%
Image(filename='20180524_184520.png')
